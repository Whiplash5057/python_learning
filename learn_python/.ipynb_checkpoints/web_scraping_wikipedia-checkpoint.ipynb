# %%
import requests, bs4

# res = requests.get('https://www.instagram.com/whiplash5057/')
# soup = bs4.BeautifulSoup(res.text, 'lxml')
# heading_list = soup.select('body')
# print(heading_list)
# Out:
# [<body class="">
# <span id="react-root"></span>
# <script type="text/javascript">window._sharedData = {"activity_counts":null,"config":{"csrf_token":"YorYQSU36iz2ybuMlTQluDTdbjn4WcDz","viewer":null},"supports_es6":false,"country_code":"IN","language_code":"en","locale":"en_US","entry_data":{"ProfilePage":[{"logging_page_id":"profilePage_984235685","show_suggested_profiles":false,"graphql":{"user":{"biography":"\ud83d\udcbb Software Architect | Model \ud83e\udd13","blocked_by_viewer":false,"country_block":false,"external_url":null,"external_url_linkshimmed":null,"edge_followed_by":{"count":384},"followed_by_viewer":false,"edge_follow":{"count":319},"follows_viewer":false,"full_name":"Richard Andrews","has_blocked_viewer":false,"highlight_reel_count":0,"has_requested_viewer":false,"id":"984235685","is_private":false,"is_verified":false,"mutual_followers":null,"profile_pic_url":"https://instagram.fbom3-1.fna.fbcdn.net/vp/dbed1ff34ca7a3a7d283ab3c5c2e94c5/5BC43A35/t51.2885-19/11850404_1646397798939252_1328711492_a.jpg","profile_pic_url_hd":"https://instagram.fbom3-1.fna.fbcdn.net/vp/dbed1ff34ca7a3a7d283ab3c5c2e94c5/5BC43A35/t51.2885-19/11850404_1646397798939252_1328711492_a.jpg","requested_by_viewer":false,"username":"whiplash5057","connected_fb_page":null,"edge_felix_video_timeline":{"count":0,"page_info":{"has_next_page":false,"end_cursor":null},"edges":[]},"edge_owner_to_timeline_media":{"count":26,"page_info":{"has_next_page":true,"end_cursor":"AQCXaB_u9Y6FfZFNLJHFp5HLPDaU2zkz3fYG8AiMucvo3wRFZPeYul0ZpsPJYCZaOpns6ZQNggA8ssdPrqdUBqb6Cjpk4hCva5NR1148vxO92g"},"edges":[{"node":{"__typename":"GraphImage","id":"1767222134542067589","edge_media_to_caption":{"edges":[{"node":{"text":"Mug shot infinity \nCredit: @hellostyfi @aqsaraval @harshana_kumari @rashika06 @ishitaagandhi @cosmoandfries @nowmee_chowdary @cae.ranee @juhivyas @claudiusallen .\n.\n.\n.\n#unudeltratedme #nofilter #natural #mugshot #light #test #vogue #hellostyfi #hobby #fashion #me  #love #profile #photography #photographers_of_india #photooftheday #picoftheday #ambition #hobby #model #modellife #modelling #beard"}}]},"shortcode":"BiGbysQlmeF","edge_media_to_comment":{"count":5},"comments_disabled":false,"taken_at_timestamp":1524889316,"dimensions":{"height":1080,"width":1080},"display_url":"https://instagram.fbom3-1.fna.fbcdn.net/vp/58d193bf2ee9c47b501e958b045782d8/5B7D88DF/t51.2885-15/e35/30602590_1986600678322331_5854172404498038784_n.jpg","edge_liked_by":{"count":160},"edge_media_preview_like":{"count":160},"gating_info":null,"media_preview":"","owner":{"id":"984235685"},"thumbnail_src":"https://instagram.fbom3-1.fna.fbcdn.net/vp/8041d73a5873b06cf0cf2ab666a1fe23/5BC344F5/t51.2885-15/s640x640/sh0.08/e35/30602590_1986600678322331_5854172404498038784_n.jpg","thumbnail_resources":[{"src":"https://instagram.fbom3-1.fna.fbcdn.net/vp/3f9e30675540af50567c546608b874e3/5B7B1D88/t51.2885-15/s150x150/e35/30602590_1986600678322331_5854172404498038784_n.jpg","config_width":150,"config_height":150},{"src":"https://instagram.fbom3-1.fna.fbcdn.net/vp/ba39cf8116a9d040b5490d0eba3a37c4/5B90FB1C/t51.2885-15/s240x240/e35/30602590_1986600678322331_5854172404498038784_n.jpg","config_width":240,"config_height":240},{"src":"https://instagram.fbom3-1.fna.fbcdn.net/vp/0cd4fe271e63fd58f2b2c3d5cdd5a522/5B880DB8/t51.2885-15/s320x320/e35/30602590_1986600678322331_5854172404498038784_n.jpg","config_width":320,"config_height":320},{"src":"https://instagram.fbom3-1.fna.fbcdn.net/vp/4ebe0677074dde7be7206275456beb3c/5B9FEDE0/t51.2885-15/s480x480/e35/30602590_1986600678322331_5854172404498038784_n.jpg","config_width":480,"config_height":480},{"src":"https://in ...
# <script type="text/javascript">
#     window.__initialDataLoaded(window._sharedData);
#     </script>
# <script crossorigin="anonymous" src="/static/bundles/base/Polyfills.js/d5d44088527a.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="/static/bundles/base/Vendor.js/03616409e70a.js" type="text/javascript"></script>
# <script type="text/javascript">!function(e){var a=window.webpackJsonp;window.webpackJsonp=function(n,r,c){for(var i,d,s,g=0,f=[];g<n.length;g++)d=n[g],o[d]&&f.push(o[d][0]),o[d]=0;for(i in r)Object.prototype.hasOwnProperty.call(r,i)&&(e[i]=r[i]);for(a&&a(n,r,c);f.length;)f.shift()();if(c)for(g=0;g<c.length;g++)s=t(t.s=c[g]);return s};var n={},o={67:0};function t(a){if(n[a])return n[a].exports;var o=n[a]={i:a,l:!1,exports:{}};return e[a].call(o.exports,o,o.exports,t),o.l=!0,o.exports}t.e=function(e){var a=o[e];if(0===a)return new Promise(function(e){e()});if(a)return a[2];var n=new Promise(function(n,t){a=o[e]=[n,t]});a[2]=n;var r=document.getElementsByTagName("head")[0],c=document.createElement("script");c.type="text/javascript",c.charset="utf-8",c.async=!0,c.timeout=12e4,c.crossOrigin="anonymous",t.nc&&c.setAttribute("nonce",t.nc),c.src=t.p+""+({0:"DebugInfoNub",1:"SettingsModules",2:"MobileStoriesPage",3:"DesktopStoriesPage",4:"ProfilePageContainer",5:"LikedByListContainer",6:"FollowListContainer",7:"CreationModules",8:"LocationPageContainer",9:"DiscoverMediaPageContainer",10:"DiscoverEmbedsPageContainer",11:"TagPageContainer",12:"UserCollectionMediaPageContainer",13:"FeedPageContainer",14:"PostPageContainer",15:"LandingPage",16:"LoginAndSignupPage",17:"ResetPasswordPageContainer",18:"MobileStoriesLoginPage",19:"DesktopStoriesLoginPage",20:"FBSignupPage",21:"MultiStepSignupPage",22:"DirectInboxPageContainer",23:"NewUserInterstitial",24:"DiscoverPeoplePageContainer",25:"TermsUnblockPage",26:"IGTVVideoUploadPageContainer",27:"DataDownloadRequestPage",28:"UserCollectionsPageContainer",29:"AccessToolViewAllPage",30:"AccessToolPage",31:"DataDownloadRequestConfirmPage",32:"ContactHistoryPage",33:"DataControlsSupportPage",34:"EmailConfirmationPage",35:"LocationsDirectoryLandingPage",36:"LocationsDirectoryCountryPage",37:"LocationsDirectoryCityPage",38:"OneTapUpsell",39:"NewTermsConfirmPage",40:"CheckpointUnderageAppealPage",41:"SuggestedDirectoryLandingPage",42:"ProfilesDirectoryLandingPage",43:"HashtagsDirectoryLandingPage",44:"OAuthPermissionsPage",45:"DirectoryPage",46:"HttpErrorPage",47:"ActivityFeedPage",48:"StoryCreationPage",49:"ParentalConsentPage",50:"ParentalConsentNotParentPage",51:"AccountPrivacyBugPage",52:"ContactInvitesOptOutPage",53:"ContactInvitesOptOutStatusPage",54:"Docpen",55:"Report",56:"Copyright",57:"SupportInfo",58:"Community",59:"Verification",60:"Challenge",61:"Consumer",62:"EmailSnoozePage",63:"EmailUnsubscribePage",64:"NotificationLandingPage"}[e]||e)+".js/"+{0:"1ed8afec9e06",1:"a1285df29030",2:"b3b761741174",3:"be1c29420f3f",4:"ca0aecd43a74",5:"d650d4f69b0d",6:"25c7673c9ae6",7:"6ac0dd60e8e1",8:"abbbee31eeae",9:"9dc366f1c7c3",10:"1fe0b983671b",11:"704701fc2937",12:"cb8036d3f6e4",13:"d8c18d2430c1",14:"86324e02f2fb",15:"19329bf93f6a",16:"e65d50041f5d",17:"a1055e903c8c",18:"d3b9d7b50c46",19:"442c9813c735",20:"73131f3c0182",21:"d2f1bb6e7193",22:"4531a3ecd019",23:"05a01c30847b",24:"745b1bcc91ed",25:"23e218442a40",26:"6214d88f844d",27:"7ac3de585393",28:"2ff5ac56e75f",29:"22c75e28a8b1",30:"6e2b714a6be4",31:"8b8ca8ffcd71",32:"028a68b60ebb",33:"9f4f023428e6",34:"d761f32cb90e",35:"0bcd65acce6c",36:"7e4876708677",37:"a174ca9f68dd",38:"25969be999c5",39:"76d478ee2f2d",40:"a3e5c9a760c5",41:"be462f46f2e6",42:"b72b28fb01ac",43:"b2811d1b3fd1",44:"db7eeb015599",45:"f5206abe8766",46:"6a7116115dd2",47:"d2ef887d21ec",48:"8c2e94ef15ac",49:"addb98584f09",50:"a17380b4d528",51:"2bc194de81e3",52:"e854f0260d71",53:"c151cdb3ab6c",54:"e1b42900af1f",55:"b1c1b0631c3e",56:"2b6caf28a5db",57:"244bf7f16043",58:"51995dee41d7",59:"c7b3c4462b3f",60:"b6398e5523cc",61:"95b2f8f9c684",62:"c9513b1ab29d",63:"87a68a403161",64:"547692b61861"}[e]+".js";var i=setTimeout(d,12e4);function d(){c.onerror=c.onload=null,clearTimeout(i);var a=o[e];0!==a&&(a&&a[1](new Error("Loading chunk "+e+" failed.")),o[e]=void 0)}return c.onerror=c.onload=d,r.appendChild(c),n},t.m=e,t.c=n,t.d=function(e,a,n){t.o(e,a)||Object.defineProperty(e,a,{configurable:!1,enumerable ...
# <script async="" charset="utf-8" crossorigin="anonymous" src="/static/bundles/base/ProfilePageContainer.js/ca0aecd43a74.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="/static/bundles/base/en_US.js/54cefa9a1bb6.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="/static/bundles/base/ConsumerCommons.js/5354a2b07380.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="/static/bundles/base/Consumer.js/95b2f8f9c684.js" type="text/javascript"></script>
# </body>]

# %%
# for item in heading_list:
#     print(item.text)

# %%
res = requests.get('https://en.wikipedia.org/wiki/Cicada_3301')
soup = bs4.BeautifulSoup(res.text, 'lxml')
image_info = soup.select('.thumbimage')
cacada = image_info[0]

image_link = 'http:' + cacada['src']
print(image_link)
# Out:
# http://upload.wikimedia.org/wikipedia/en/thumb/7/7e/Cicada_3301_logo.jpg/220px-Cicada_3301_logo.jpg
